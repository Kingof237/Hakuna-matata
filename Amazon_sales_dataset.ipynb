# %%
## Data Analysis Of an Amazon Dataset 
## Source: Kaggle

# %%
### Presentation of the Data

# This dataset contains 1K+ Amazon Product's Ratings and Reviews as per their details listed on the official website of Amazon

# %%
# Data Cleaning and Preparation

# %%
#Import Modules

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# load data into notebook

df=pd.read_csv("amazon_data_set.csv")
df.head(5)
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# ...

# %%
df.shape
# Out:
# (1465, 16)

# %%
#Check if any duplicate
df.duplicated().value_counts()
# Out:
# False    1465
# dtype: int64

# %%
#create a copy to avoid altering original
dfx=df.copy()

# %%
#Check if any missing value
dfx.isna().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           2
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %%
#Select rows with missing value
dfx[dfx["rating_count"].isna()]
# Out:
#      product_id                                       product_name  \
# 282  B0B94JPY2N  Amazon Brand - Solimo 65W Fast Charging Braide...
# 324  B0BQRJ3C47  REDTECH USB-C to Lightning Cable 3.3FT, [Apple...
#
#                                               category discounted_price  \
# 282  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 324  Computers&Accessories|Accessories&Peripherals|...             ₹249
#
#     actual_price discount_percentage rating rating_count  \
# 282         ₹999                 80%    3.0          NaN
# 324         ₹999                 75%    5.0          NaN
#
#                                          about_product  \
# 282  USB C to C Cable: This cable has type C connec...
# 324  💎[The Fastest Charge] - This iPhone USB C cabl...
#
#                           user_id    user_name      review_id  \
# 282  AE7CFHY23VAJT2FI4NZKKP6GS2UQ       Pranav   RUB7U91HVZ30
# 324  AGJC5O5H5BBXWUV7WRIEIOOR3TVQ  Abdul Gafur  RQXD5SAMMPC6L
#
# ...

# %%
# Drop missing value
dfx=dfx.dropna()

# %%
dfx.isna().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           0
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %%
# Check for Data types
dfx.dtypes
# Out:
# product_id             object
# product_name           object
# category               object
# discounted_price       object
# actual_price           object
# discount_percentage    object
# rating                 object
# rating_count           object
# about_product          object
# user_id                object
# user_name              object
# review_id              object
# review_title           object
# review_content         object
# img_link               object
# product_link           object
# dtype: object

# %%
# change data types to float or integer
dfx["rating_count"]=dfx["rating_count"].str.replace(",","")
dfx["discounted_price"]=dfx["discounted_price"].str.replace("₹","").str.replace(".","").str.replace(",","")
dfx["discount_percentage"]=dfx["discount_percentage"].str.rstrip("%")
dfx["discounted_price"]=dfx["discounted_price"].astype(float)
dfx["actual_price"]=dfx["actual_price"].str.replace("₹","").str.replace(",","")
dfx["actual_price"]=dfx["actual_price"].str.replace(".","")
dfx["actual_price"]=dfx["actual_price"].astype(int)
dfx["discount_percentage"]=dfx["discount_percentage"].astype(float)
dfx["rating_count"]=dfx["rating_count"].astype(int)

# %%
#change values in percentage
dfx["discount_percentage"]=dfx["discount_percentage"]/100

# %%
dfx["discount_percentage"]
# Out:
# 0       0.64
# 1       0.43
# 2       0.90
# 3       0.53
# 4       0.61
#         ...
# 1460    0.59
# 1461    0.25
# 1462    0.28
# 1463    0.26
# 1464    0.22
# Name: discount_percentage, Length: 1463, dtype: float64

# %%
# locate non numeric value
dfx[["rating"]].value_counts()
# Out:
# rating
# 4.1       244
# 4.3       230
# 4.2       228
# 4.0       129
# 3.9       123
# 4.4       123
# 3.8        86
# 4.5        75
# 4          52
# 3.7        42
# 3.6        35
# 3.5        26
# 4.6        17
# 3.3        16
# 3.4        10
# 4.7         6
# 3.1         4
# 4.8         3
# 2.8         2
# 5.0         2
# 3.2         2
# 3.0         2
# 2.3         1
# 2.6         1
# |           1
# 2.9         1
# 3           1
# 2           1
# dtype: int64

# %%
# Replace by 4 (Data picked on the AMZ website)
dfx["rating"]=dfx["rating"].str.replace("|","4")

# %%
# Change datatype
dfx["rating"].astype(float)
# Out:
# 0       4.2
# 1       4.0
# 2       3.9
# 3       4.2
# 4       4.2
#        ...
# 1460    4.0
# 1461    4.1
# 1462    3.6
# 1463    4.0
# 1464    4.3
# Name: rating, Length: 1463, dtype: float64

# %%
dfx.dtypes
# Out:
# product_id              object
# product_name            object
# category                object
# discounted_price       float64
# actual_price             int32
# discount_percentage    float64
# rating                  object
# rating_count             int32
# about_product           object
# user_id                 object
# user_name               object
# review_id               object
# review_title            object
# review_content          object
# img_link                object
# product_link            object
# dtype: object

# %%
#Split category column
df2=dfx["category"].str.split("|",expand=True)
df2
# Out:
#                           0                           1  \
# 0     Computers&Accessories     Accessories&Peripherals
# 1     Computers&Accessories     Accessories&Peripherals
# 2     Computers&Accessories     Accessories&Peripherals
# 3     Computers&Accessories     Accessories&Peripherals
# 4     Computers&Accessories     Accessories&Peripherals
# ...                     ...                         ...
# 1460           Home&Kitchen      Kitchen&HomeAppliances
# 1461           Home&Kitchen      Kitchen&HomeAppliances
# 1462           Home&Kitchen  Heating,Cooling&AirQuality
# 1463           Home&Kitchen  Heating,Cooling&AirQuality
# 1464           Home&Kitchen      Kitchen&HomeAppliances
#
#                                2                         3          4     5  \
# 0             Cables&Accessories                    Cables  USBCables  None
# 1             Cables&Accessories                    Cables  USBCables  None
# ...

# %%
df2 = df2.rename(columns={0:'category_1', 1:'category_2'})

# %%
dfx["Major_category"]=df2["category_1"]

dfx["Sub_category"]=df2["category_2"]

# %%
dfx.drop(columns="category",inplace=True)

# %%
dfx["product_id"].str.strip()
# Out:
# 0       B07JW9H4J1
# 1       B098NS6PVG
# 2       B096MSW6CT
# 3       B08HDJ86NZ
# 4       B08CF3B7N1
#            ...
# 1460    B08L7J3T31
# 1461    B01M6453MB
# 1462    B009P2LIL4
# 1463    B00J5DYCCA
# 1464    B01486F4G6
# Name: product_id, Length: 1463, dtype: object

# %%
dfx.drop(columns={"img_link","product_link"},inplace=True)

# %%
dfx["rating"]=dfx["rating"].astype(float)

# %%
dfx.dtypes
# Out:
# product_id              object
# product_name            object
# discounted_price       float64
# actual_price             int32
# discount_percentage    float64
# rating                 float64
# rating_count             int32
# about_product           object
# user_id                 object
# user_name               object
# review_id               object
# review_title            object
# review_content          object
# Major_category          object
# Sub_category            object
# dtype: object

# %%
# Add a score column
dfx['Score'] = pd.cut(x=dfx['rating'], bins=[1, 3, 4, 5],
                     labels=['Low', 'Medium', 'High'])
dfx[["rating","Score"]].value_counts()
# Out:
# rating  Score
# 4.1     High      244
# 4.3     High      230
# 4.2     High      228
# 4.0     Medium    182
# 3.9     Medium    123
# 4.4     High      123
# 3.8     Medium     86
# 4.5     High       75
# 3.7     Medium     42
# 3.6     Medium     35
# 3.5     Medium     26
# 4.6     High       17
# 3.3     Medium     16
# 3.4     Medium     10
# 4.7     High        6
# 3.1     Medium      4
# 3.0     Low         3
# 4.8     High        3
# 2.8     Low         2
# 5.0     High        2
# 3.2     Medium      2
# 2.9     Low         1
# 2.6     Low         1
# 2.3     Low         1
# 2.0     Low         1
# dtype: int64

# %%
#Split user_id and user_name
userid_split=dfx["user_id"].str.split(",",expand=False)
userid_split=userid_split.explode()
userid_split=userid_split.reset_index(drop=True)

username_split=dfx["user_name"].str.split(",",expand=False)
username_split=username_split.explode()
username_split=username_split.reset_index(drop=True)

# %%
# Create Dataframe
df3=pd.DataFrame(userid_split)
df3=df3.reset_index(drop=True)
df4=pd.DataFrame(username_split)
df4=df6.reset_index(drop=True)

# %%
# Merge both dataframes
merge_user= pd.merge(df3, df4, left_index=True, right_index=True)
merge_user
# Out:
#                             user_id          user_name
# 0      AG3D6O4STAQKAY2UVGEUV46KN35Q              Manav
# 1      AHMY5CWJMMK5BJRBBSNLYT3ONILA       Adarsh gupta
# 2      AHCTC6ULH4XB6YHDY6PCH2R772LQ            Sundeep
# 3      AGYHHIERNXKA6P5T7CZLXKVPT7IQ     S.Sayeed Ahmed
# 4      AG4OGOFWXJZTQ2HKYIOCOY3KXF2Q     jaspreet singh
# ...                             ...                ...
# 11496  AHXCDNSXAESERITAFELQABFVNLCA  BATTU SURESHKUMAR
# 11497  AGRZD6CHLCUNOLMMIMIHUCG7PIFA      Shubham Dubey
# 11498  AFQZVGSOSOJHKFQQMCEI4725QEKQ        E.GURUBARAN
# 11499  AEALVGXXIP46OZVXKRUXSDWZJMEA          Mayank S.
# 11500  AGEFL3AY7YXEFZA4ZJU3LP7K7OJQ         eusuf khan
#
# [11501 rows x 2 columns]

# %%
#Create a pivot Table
dfx1=dfx[["Major_category","Sub_category","product_id"]]
dfx2=pd.pivot_table(dfx1 ,index=["Major_category","Sub_category" ],aggfunc="count")

# %%
dfx2
# Out:
#                                                                product_id
# Major_category        Sub_category
# Car&Motorbike         CarAccessories                                    1
# Computers&Accessories Accessories&Peripherals                         379
#                       Components                                        5
#                       ExternalDevices&DataStorage                      18
#                       Laptops                                           1
#                       Monitors                                          2
#                       NetworkingDevices                                34
#                       Printers,Inks&Accessories                        11
#                       Tablets                                           1
# Electronics           Accessories                                      14
#                       Cameras&Photography                              16
# ...
